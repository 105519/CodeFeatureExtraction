# %%
import os
import json
import random
import tokenize
from tqdm import tqdm
import multiprocessing

from sentence_transformers import SentenceTransformer
sentence_model = SentenceTransformer('all-MiniLM-L6-v2')

from transformers import RobertaTokenizer
tokenizer = RobertaTokenizer.from_pretrained('microsoft/codebert-base')

topics = ['algorithm', 'aws', 'bitcoin', 'bot', 'compiler', 'covid-19',
          'learning', 'django', 'git', 'google', 'graphql', 'kubernetes']

class arguments(object):
    def __init__(self):
        pass
args = arguments()
args.total_length = 512

# %%
def cnt_python(path):
    if (os.path.isdir(path)):
        ans = 0
        for x in os.listdir(path):
            ans += cnt_python(path + '/' + x)
        return ans
    else:
        assert(os.path.isfile(path))
        return 0 + (path[-3 :] == '.py')

def get_repos(filepath, itempath, structurepath):
    repos = []
    for dir1 in os.listdir(filepath):
        assert(os.path.isdir(filepath + '/' + dir1))
        if (not os.path.isdir(itempath + '/' + dir1)):
            continue
        for dir2 in os.listdir(filepath + '/' + dir1):
            assert(os.path.isdir(filepath + '/' + dir1 + '/' + dir2))
            if (not os.path.isdir(itempath + '/' + dir1 + '/' + dir2)):
                continue
            cnt = cnt_python(filepath + '/' + dir1 + '/' + dir2)
            if (cnt > 1000):
                continue
            repos.append(dir1 + '/' + dir2)
    return repos

filepath = '../data/github-repos/files'
itempath = '../data/github-repos/item'
structurepath = '../data/github-repos/structure'
repos = get_repos(filepath, itempath, structurepath)

# %%
def read_label(repos, filepath):
    labels = []
    for repo in tqdm(repos):
        assert(os.path.isfile(filepath + '/' + repo + '/' + 'item.jsonl'))
        f = open(filepath + '/' + repo + '/' + 'item.jsonl', 'r')
        item = json.loads(f.readline())
        labels.append(item['topics'])
        f.close()
    return labels

labels = read_label(repos, '../data/github-repos/item')
for i in range(len(labels)):
    labels[i] = ['algorithm' if x == 'algorithms' else x for x in labels[i]]
    labels[i] = ['learning' if 'learn' in x else x for x in labels[i]]
    labels[i] = list(set(labels[i]))
labels01 = [[x in label for x in topics] for label in labels]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23088/23088 [00:01<00:00, 13156.71it/s]

# %%
repos = [x for x, y in zip(repos, labels01) if sum(y) != 0]
labels = read_label(repos, '../data/github-repos/item')
for i in range(len(labels)):
    labels[i] = ['algorithm' if x == 'algorithms' else x for x in labels[i]]
    labels[i] = ['learning' if 'learn' in x else x for x in labels[i]]
    labels[i] = list(set(labels[i]))
labels01 = [[x in label for x in topics] for label in labels]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12272/12272 [00:00<00:00, 13217.44it/s]

# %%
def label_cnter(labels):
    cnter = dict()
    for x in labels:
        for y in x:
            if (y in cnter):
                cnter[y] += 1
            else:
                cnter[y] = 1
    for x in topics:
        print(x, cnter[x])
# label_cnter(labels)

# %%
def get_tokens(code, do_remove, tmp_file_name, path):
    if (do_remove):
        try:
            code = remove_comments_and_docstrings(code, 'python')
        except:
            pass
    output_file = open(tmp_file_name, 'w')
    print(code, file = output_file)
    output_file.close()
    
    tokens = []
    f = open(tmp_file_name, 'rb')
    tokenGenerator = tokenize.tokenize(f.readline)
    for token in tokenGenerator:
        if (token.type in [0, 59, 60, 62]): # COMMENT
            pass
        elif (token.type in [4, 61]): # NEWLINE
            pass
        elif (token.type == 5): # INDENT
            pass
        elif (token.type == 6): # DEDENT
            pass
        elif (token.type in [1, 2, 3, 54]): # NAME NUMBER STRING OP
            tokens.append(token.string)
        else:
            assert(False)
        if (len(tokens) > 1.5 * args.total_length):
            break
    f.close()
    return tokens

def tokenized_code(tokens):
    if (tokens != []):
        tokens = [tokenizer.tokenize(tokens[0])] \
               + [tokenizer.tokenize('@ ' + x)[1 :] for x in tokens[1 :]]
        tokens = [y for x in tokens for y in x]
        tokens = tokens[: args.total_length - 2]
    code_ids = [tokenizer.cls_token_id] + tokenizer.convert_tokens_to_ids(tokens)
    padding_length = args.total_length - len(code_ids)
    code_ids += [tokenizer.pad_token_id] * padding_length
    return code_ids

def search(path, idx):
    data = []
    if (os.path.isdir(path)):
        for x in os.listdir(path):
            data.extend(search(path + '/' + x, idx))
    else:
        assert(os.path.isfile(path))
        if (path[-3 :] != '.py'):
            return []
        input_file = open(path, 'r')
        try:
            code = input_file.read()
        except:
            f = open('../data/badfile.txt', 'a')
            print(path, file = f)
            f.close()
            return []
        tmp_file_name = str(idx) + '.py'
        try:
            tokens = get_tokens(code, True, tmp_file_name, path)
        except:
#             tokens = get_tokens(code, False, tmp_file_name, path)
            try:
                tokens = get_tokens(code, False, tmp_file_name, path)
            except:
                print(path)
                os.system('rm ./' + tmp_file_name)
                return []
        os.system('rm ./' + tmp_file_name)
        if (tokens != []):
            data.append(tokenized_code(tokens))
        input_file.close()
    return data

def read_data(repos, filepath):
    print(len(repos))
    dataset = []
    pool = multiprocessing.Pool(processes = 50)
    for idx, repo in enumerate(repos):
        dataset.append(pool.apply_async(search, (filepath + '/' + repo, idx, )))
    pool.close()
    pool.join()
    for i in range(len(dataset)):
        dataset[i] = dataset[i].get()
    return dataset
    
#     dataset = []
#     for idx, repo in enumerate(tqdm(repos)):
#         data = search(filepath + '/' + repo, idx)
#         dataset.append(data)
#     return dataset

# %%
def get_graph(path):
    nodes = {}
    file = open(path + '/node.txt')
    context = file.read()
    context = context.strip().split('\n')
    file.close()
    for x in context[1 :]:
        try:
            node_id = int(x[0 : x.find(',')])
            node_type = x[x.find(',') + 1 : x.find(',', x.find(',') + 1)]
            node_name = x[x.find(',', x.find(',') + 1) + 1 : x.rfind(',')]
            node_father = int(x[x.rfind(',') + 1 :])
        except:
            print(x)
            print(x[0 : x.find(',')])
            print(x[x.find(',') + 1 : x.find(',', x.find(',') + 1)])
            print(x[x.find(',', x.find(',') + 1) + 1 : x.rfind(',')])
            print(x[x.rfind(',') + 1 :])
            assert(False)
        assert(node_id not in nodes)
        if (node_name.find('data/github-repos/files') != -1):
            node_name = node_name[node_name.find('data/github-repos/files') + 24 :]
        nodes[node_id] = (node_type, node_name, node_father)
    
    edges = []
    file = open(path + '/edge.txt')
    context = file.read()
    context = context.strip().split('\n')
    file.close()
    for x in context[1 :]:
        source = int(x[: x.find(',')])
        target = int(x[x.find(',') + 1 : x.find(',', x.find(',') + 1)])
        if ((source in nodes) and (target in nodes)):
            edges.append([source, target])
    for node_id in nodes:
        node_father = nodes[node_id][2]
        if (node_father in nodes):
            edges.append([node_father, node_id])
        else:
            assert(node_father == -1)
    return nodes, edges

def cut_graph(nodes, edges):
    keep = set()
    left = set()
    E = {}
    for x in nodes:
        E[x] = []
        left.add(x)
    for u, v in edges:
        E[u].append(v)
        E[v].append(u)
    
    while (len(keep) < min(200, len(nodes))):
        root = random.sample(left, 1)[0]
        keep.add(root)
        left.remove(root)
        flag = True
        while (flag):
            flag = False
            consider = set()
            for u in keep:
                for v in E[u]:
                    consider.add(v)
            consider = consider & left
            consider = random.sample(consider, min(len(consider), 200 - len(keep)))
            for x in consider:
                keep.add(x)
                left.remove(x)
                flag = True
    
    new_nodes = []
    new_edges = []
    idmap = {}
    for idx, x in enumerate(keep):
        new_nodes.append(nodes[x][1])
        idmap[x] = idx
    for (u, v) in edges:
        if ((u in idmap) and (v in idmap)):
            new_edges.append([idmap[u], idmap[v]])
    return new_nodes, new_edges

def read_graph(repos, filepath):
    graphs = []
    for repo in tqdm(repos):
        nodes = []
        edges = []
        if (os.path.isfile(structurepath + '/' + repo + '/node.txt')):
            assert(os.path.isfile(structurepath + '/' + repo + '/edge.txt'))
            nodes, edges = get_graph(structurepath + '/' + repo)
            nodes, edges = cut_graph(nodes, edges)
        graphs.append([nodes, edges])
    return graphs

# %%
def read_description(repos, filepath):
    description = []
    for repo in tqdm(repos):
        if (not os.path.isfile(filepath + '/' + repo + '/' + 'description.md')):
            context = ''
        else:
            f = open(filepath + '/' + repo + '/' + 'description.md', 'r')
            context = f.read()
            f.close()
        description.append(sentence_model.encode(context).tolist())
    return description

def read_readme(repos, filepath):
    readme = []
    for repo in tqdm(repos):
        if (not os.path.isfile(filepath + '/' + repo + '/' + 'README.md')):
            context = ''
        else:
            try:
                f = open(filepath + '/' + repo + '/' + 'README.md', 'r')
                context = f.read()
                f.close()
            except:
                context = ''
        readme.append(sentence_model.encode(context).tolist())
    return readme

# %%
dataset = read_data(repos, '../data/github-repos/files')
graphs = read_graph(repos, '../data/github-repos/item')
description = read_description(repos, '../data/github-repos/item')
readme = read_readme(repos, '../data/github-repos/files')
# Out:
# 12272
# ../data/github-repos/files/Snivyn/raffle-scripts/GetMyLevisJordans%20-%20Levis%20x%20Air%20Jordan%204%20-Black-%20-White/main.py
# ../data/github-repos/files/SoumanRoy/MachineLearning/Linear_Regression_Gradient_Descent/gradient_descent.py
# ../data/github-repos/files/hariharanragothaman/problemsets/leetcode/0509_fibonacci_number.py
# ../data/github-repos/files/ojasvin/Data-Structures-and-Algorithms-codes/CS_LAB_MA252/graphalgorithms/Bipartite/Bipartite.py
# ../data/github-repos/files/Mendes1302/Python-Learning/Learn/WAGE ADJUSTMENT.py
# ../data/github-repos/files/Block-Chen/blocksdk-python/BlockSDK/market.py
# ../data/github-repos/files/vwang0/Leetcode_Solutions/Algorithms_easy/0136. SingleNumber.py
# ../data/github-repos/files/CUBigDataClass/Indian-Premier-League/code/player_birth_info.py
# ../data/github-repos/files/Badhansen/python-working-dictionary/Lynda%20Python%203/18%20Debugging/saytime-errors.py
# ../data/github-repos/files/sk-g/Leetcode/python/191. Number of 1 Bits.py
# ../data/github-repos/files/vwang0/Leetcode_Solutions/Algorithms_easy/0228. Summary Ranges.py
# ../data/github-repos/files/Bennyhwanggggg/Algorithm-and-Data-Structures-and-Coding-Challenges/Challenges/maxProfitWithKTransactions.py
# ../data/github-repos/files/Bennyhwanggggg/Algorithm-and-Data-Structures-and-Coding-Challenges/Challenges/inplaceFrequencyCount.py
# ../data/github-repos/files/deepanshululla/DataStructuresAndAlgo/python/trees/binaryHeap.py
# ../data/github-repos/files/aimi-cn/AILearners/data/ml/jqxxsz/sourceData/Ch15/proximalSVM.py
# ../data/github-repos/files/vwang0/Leetcode_Solutions/Algorithms_hard/1724. Checking Existence of Edge Length Limited Paths II.py
# ../data/github-repos/files/Bennyhwanggggg/Algorithm-and-Data-Structures-and-Coding-Challenges/Challenges/twoSumLessThanK.py
# ../data/github-repos/files/gaurav-karna/Ocularis/Ocularis_PY_Platform/main_raspi_version.py
# ../data/github-repos/files/Bennyhwanggggg/Algorithm-and-Data-Structures-and-Coding-Challenges/Challenges/superUglyNumber.py
# ../data/github-repos/files/alfredholmes/CryptoBots/cryptobots/maths/graphs.py
# ../data/github-repos/files/Bennyhwanggggg/Algorithm-and-Data-Structures-and-Coding-Challenges/Challenges/decodeStringII.py
# ../data/github-repos/files/abitofalchemy/Scriptus/pyths/prsSubdue.py
# ../data/github-repos/files/heqin-zhu/algorithm/dynamicProgramming/stoneGame.py
# ../data/github-repos/files/Bennyhwanggggg/Algorithm-and-Data-Structures-and-Coding-Challenges/Data-Structures/Linked%20lists/doubly_linked_list_adt.py
# ../data/github-repos/files/Bennyhwanggggg/Algorithm-and-Data-Structures-and-Coding-Challenges/Linked%20Lists/doubly_linked_list_adt.py
# ../data/github-repos/files/abitofalchemy/Scriptus/pyths/dsg1/games_info.py
# ../data/github-repos/files/abitofalchemy/Scriptus/pyths/dsg1/mysql_dsg1.py
# ../data/github-repos/files/abitofalchemy/Scriptus/pyths/last_session.py
# ../data/github-repos/files/vwang0/Leetcode_Solutions/Cracking_the_Coding_Interview/3_2_stack_with_minimum.py
# ../data/github-repos/files/DemocracyEarth/micropayment-voting/src/api.py
# ../data/github-repos/files/abitofalchemy/Scriptus/experimentalist/two/one_dgl.py
# ../data/github-repos/files/vwang0/Leetcode_Solutions/misc/Common elements in two sorted lists.py
# ../data/github-repos/files/amitjoshi9627/PythonDSA/knight_problem.py
# ../data/github-repos/files/amitjoshi9627/PythonDSA/quickSort.py
# ../data/github-repos/files/kenshinji/codingbat_python/String-2/cat_dog.py
# ../data/github-repos/files/IAmAbszol/DailyProgrammingChallenges/DailyProgrammingBookChallenges/Chapter_6/reconstruct.py
# ../data/github-repos/files/CoodingPenguin/problem-solving/boj/4153_직각삼각형.py
# ../data/github-repos/files/FarzanaEva/Data-Structure-and-Algorithm-Practice/InterviewBit%20Problems/Trees/kth_smallest_element_in_the_tree.py
# ../data/github-repos/files/FarzanaEva/Data-Structure-and-Algorithm-Practice/InterviewBit%20Problems/Trees/symmetric_binary_tree.py
# ../data/github-repos/files/zillow/hyper-kube-config/homebrew/get-homebrew-formula-vars.py
# ../data/github-repos/files/CoodingPenguin/problem-solving/boj/7568_덩치.py
# ../data/github-repos/files/CoodingPenguin/problem-solving/boj/11054_가장긴바이토닉부분수열_2.py
# ../data/github-repos/files/aniruddhamurali/python-algorithms/src/searching/jump_search.py
# ../data/github-repos/files/FarzanaEva/Data-Structure-and-Algorithm-Practice/InterviewBit%20Problems/Linked%20Lists/remove_nth_node_from_list_end.py
# ../data/github-repos/files/CoodingPenguin/problem-solving/boj/2798_블랙잭.py
# ../data/github-repos/files/yuzhoujr/leetcode/tree/EricD/437. Path Sum III - EricD.py
# ../data/github-repos/files/Komal97/DS-Algortihms/10.%20Linked%20List/Python/detect_cycle_using_floyd.py
# ../data/github-repos/files/julianyulu/AlgorithmsNotes/practice/binary_tree/BaiDu_interview_20181031.py
# ../data/github-repos/files/denniskraus14/BlockchainDemo/blockchain.py
# ../data/github-repos/files/andreafiori/python-coding-dojo/src/online/leetcode/nth_digit.py
# ../data/github-repos/files/yennanliu/CS_basics/leetcode_python/Sort/meeting-rooms-ii.py
# ../data/github-repos/files/sushmita2609/Coding-Prep/db.py
# ../data/github-repos/files/andreafiori/python-coding-dojo/src/online/leetcode/number_of_segments_in_a_string.py
# ../data/github-repos/files/liadbiz/Leetcode-Solutions/src/python/dynamic_programming/guess_number_higher_or_lower_2.py
# ../data/github-repos/files/jseric/stem_games-fesbovci/source_code/level_01/pillars/pillars.py
# ../data/github-repos/files/yennanliu/CS_basics/leetcode_python/Dynamic_Programming/coin-change.py
# ../data/github-repos/files/jbrower95/crop/ropgadget/ropchain/arch/ropmaker.py
# ../data/github-repos/files/yennanliu/CS_basics/leetcode_python/Design/design_search_autocomplete_system.py
# ../data/github-repos/files/yennanliu/CS_basics/workspace/Pipeline/gameApp/etl/batch/load.py
# ../data/github-repos/files/AbhiSaphire/Competitive-Programming-Solutions/Coding%20Club%20India/Asked%20Amazon%20Interview%20Questions/MinimumPlatforms.py
# ../data/github-repos/files/DeachSword/CHRLINE/examples/remove_e2ee_key.py
# ../data/github-repos/files/DeepNinja07x/Python_Scripts/Algorithms/kadaneAlgorithm.py
# ../data/github-repos/files/DeepNinja07x/Python_Scripts/Basic%20Scripts/CurrencyConverter.py
# ../data/github-repos/files/lukewalt/algorithms/kruskal.py
# ../data/github-repos/files/jjfiv/mm2019/mm12574.py
# ../data/github-repos/files/Zeeshanahmad4/My-Path-to-Python/Selenium.py
# ../data/github-repos/files/Zeeshanahmad4/My-Path-to-Python/Python.py
# ../data/github-repos/files/Zeeshanahmad4/My-Path-to-Python/Django.py
# ../data/github-repos/files/EkantBajaj/leetcode-Questions/819. Most Common Word.py
# ../data/github-repos/files/EkantBajaj/leetcode-Questions/46.Permutations.py
# ../data/github-repos/files/AllAlgorithms/python/algorithms/strings/pattern_match.py
# ../data/github-repos/files/carbonsteel/fer/py/fer/grammer/bstream.py
# ../data/github-repos/files/Jumaruba/URI/PYTHON/2022(incomplet).py
# ../data/github-repos/files/hongtsingwang/simhash/repeating_data_process.py
# ../data/github-repos/files/indrz/indrz-be/indrz/settings/production.py
# ../data/github-repos/files/8luebottle/DataStructure-N-Algorithm/Data_Structure/tree.py
# ../data/github-repos/files/sksmslhy/Java_Lexical_and_Syntax_Analyzer/lexical%20analyzer/DFA/LiteralStirng.py
# ../data/github-repos/files/moueza/covid19-corona-virus-scilab/PYTHON/poub10.py
# ../data/github-repos/files/wally-wally/Solving_Problem/Programmers/Python/Level3/네트워크.py
# ../data/github-repos/files/miztiik/my-first-cdk-project/resource_stacks/custom_ec2_with_ebs_piops.py
# ../data/github-repos/files/BlueGranite/DatabricksTraining/Notebooks/05 - Data Engineering 3.py
# ../data/github-repos/files/ywzhou123/EWP_OMS/media/EWP_OMS/SalltMater/salt/_grains/info.py
# ../data/github-repos/files/ywzhou123/EWP_OMS/media/EWP_OMS/SalltMater/salt/_modules/puppet.py
# ../data/github-repos/files/rajitbanerjee/google-foobar/2.2-gearing-up-for-destruction/solution.py
# ../data/github-repos/files/soo5717/2021-Algorithm-Study/Programmers/jiwoo/sort/K번째수.py
# ../data/github-repos/files/Alohomora-team/AlohomoraAPI/app/bot/apps.py
# ../data/github-repos/files/Alohomora-team/AlohomoraAPI/app/core/apps.py
# ../data/github-repos/files/Alohomora-team/AlohomoraAPI/app/core/management/commands/loadinitialdata.py
# ../data/github-repos/files/Alohomora-team/AlohomoraAPI/app/condos/apps.py
# ../data/github-repos/files/Alohomora-team/AlohomoraAPI/app/accounts/apps.py
# ../data/github-repos/files/vpaliy/twitter-scraper/tweebot/actions.py
# ../data/github-repos/files/vpaliy/merklelib/tests/test_merkle.py
# ../data/github-repos/files/vpaliy/merklelib/benchmark/__main__.py../data/github-repos/files/vpaliy/twitter-scraper/tweebot/handlers.py
#
# ../data/github-repos/files/vpaliy/twitter-scraper/tweebot/_base.py
# ../data/github-repos/files/vpaliy/twitter-scraper/tweebot/agents.py
# ../data/github-repos/files/vpaliy/twitter-scraper/tweebot/__main__.py
# ../data/github-repos/files/vpaliy/merklelib/merklelib/format.py
# ../data/github-repos/files/vpaliy/merklelib/merklelib/merkle.py
# ../data/github-repos/files/ianxin/Algorithm/src/merge_sort.py
# ../data/github-repos/files/ianxin/Algorithm/src/binarySearch.py
# ../data/github-repos/files/ianxin/Algorithm/src/removeElement.py
# ../data/github-repos/files/miso-choi/algorithm_python/%EC%9D%B4%EA%B2%83%EC%9D%B4_%EC%B7%A8%EC%97%85%EC%BD%94%ED%85%8C/%EA%B5%AC%ED%98%84/왕실의나이트.py
# ../data/github-repos/files/rldotai/rl-algorithms/py3/htd.py
# ../data/github-repos/files/afriedsam/Python-BTC-Twitter-Bot/TwitterBot.py
# ../data/github-repos/files/algo-itzy/algo-itzy/BOJ/stack/01874-%EC%8A%A4%ED%83%9D_%EC%88%98%EC%97%B4/01874-스택_수열-yeonju.py
# ../data/github-repos/files/thundergolfer/sudkamp-langs-machines-python/sudkampPython/regex.py
# ../data/github-repos/files/ayushi7rawat/Gooogle-Foobar/Level%202/GearingUpforDestruction/solution.py
# ../data/github-repos/files/thundergolfer/sudkamp-langs-machines-python/sudkampPython/grammars/factories/contextFreeFactory.py
# ../data/github-repos/files/thundergolfer/sudkamp-langs-machines-python/sudkampPython/grammars/factories/regularFactory.py
# ../data/github-repos/files/Kartik17/PointRCNN-Argoverse/lib/datasets/custom_dataset.py
# ../data/github-repos/files/algo-itzy/algo-itzy/BOJ/set-map_by_hashing/17219-%EB%B9%84%EB%B0%80%EB%B2%88%ED%98%B8_%EC%B0%BE%EA%B8%B0/17219-비밀번호_찾기-yeonju.py
# ../data/github-repos/files/crossclaim/btcrelay-sol/test/pytest/test_storeHeaders.py
# ../data/github-repos/files/kapoor-rakshit/Miscellaneous/py_exception-handling.py
# ../data/github-repos/files/kapoor-rakshit/Miscellaneous/py_iterators.py
# ../data/github-repos/files/alibaba/AliceMind/PALM/prepro/data_builder.py
# ../data/github-repos/files/soran-ghadri/NUSCCF/model/helpers/helper.py
# ../data/github-repos/files/algo-itzy/algo-itzy/BOJ/dfs/01012-%EC%9C%A0%EA%B8%B0%EB%86%8D_%EB%B0%B0%EC%B6%94/01012-유기농_배추-yeonju.py
# ../data/github-repos/files/ShinhyeongPark/Algorithm/Level2/programmers_짝지어제거하기.py
# ../data/github-repos/files/trezor/trezor-core/mocks/generated/trezorcrypto/monero.py
# ../data/github-repos/files/Angel-Hair/XUN_Bot/xunbot/plugins/lunarcalendar/pyLunarCalendar/scrape.py
# ../data/github-repos/files/mdarman187/Covid-19-Tracker/main.py
# ../data/github-repos/files/maxim5/code-inspector/data/python/afcd0cd432842f6959c340afc0bb772b_Algorithm 19.py
# ../data/github-repos/files/aquario-crypto/Book_on_Python_Algorithms_and_Data_Structure/book/ebook_src/abstract_structures/heap/merge_sorted_seqs.py
# ../data/github-repos/files/aquario-crypto/Book_on_Python_Algorithms_and_Data_Structure/book/ebook_src/real_interview_problems/linked_list.py
# ../data/github-repos/files/xxhyowon/Algorithm-Python/[012] 핸드폰 번호 가리기.py
# ../data/github-repos/files/wir-coders/Hacktoberfest/Beginner/03.%20Python/faceRecog.py
# ../data/github-repos/files/wir-coders/Hacktoberfest/Beginner/03.%20Python/snake.py
# ../data/github-repos/files/skshahriarahmedraka/python-practice/r147_stack.py
# ../data/github-repos/files/pannous/angle/angle/precedence_parser.py
# ../data/github-repos/files/dev1911/drone_plus_plus/api/logistics/logistics/drone/drone_scheduler.py
# ../data/github-repos/files/fsiddh/Python-and-Django-Full-Stack-Web-Developer-Bootcamp/Section%2015-%20%20Python%20-%20Level%20Two/Part4_Errors_and_Exceptions.py
# ../data/github-repos/files/Palash51/Python-Programs/old_prgm/dynamic_arr.py
# ../data/github-repos/files/VitamintK/AlgorithmProblems/icpc/2016_northwestern_europe_regional/F_freeweights.py
# ../data/github-repos/files/LearnEarn-Fun/100-Days-of-Python/Day%201:%20Print,%20Len,%20Input,%20Variables/(Coding%20Excerise)%20Debugging%20Practice/main.py
# ../data/github-repos/files/neurodata/ndstore/scripts/onetime/deprecated/newMerge.py
# ../data/github-repos/files/VitamintK/AlgorithmProblems/miscellaneous/hacktech-heat/computers_nonmistaken.py
# ../data/github-repos/files/DantrazTrev/Neural-Networks/network.py
# ../data/github-repos/files/DKU-STUDY/Algorithm/LeetCode/Math/Day_of_the_Year/HyeonJeong.py
# ../data/github-repos/files/VitamintK/AlgorithmProblems/acm-practice/equalsRange.py
# ../data/github-repos/files/erick-marin/Google-ITAutomation-Python/Course_1/Week_3/pratice_quiz_recursion.py
# ../data/github-repos/files/LoveFishSoup/PackageRankSystem/model/__init__.py
# ../data/github-repos/files/nathanbaleeta/eroster/eroster/models/users.py
# ../data/github-repos/files/nathanbaleeta/eroster/eroster/models/question.py
# ../data/github-repos/files/Schrolli91/BOSWatch/plugins/FFAgent/FFAgent.py
# ../data/github-repos/files/HuberTRoy/leetCode/Array/Pascal's TriangleI_II.py
# ../data/github-repos/files/mediassumani/TechInterviewPrep/ProblemSolving/add_two_numbers.py
# ../data/github-repos/files/arbitrarymahi/problem-solving-with-algorithms-and-data-Structures-using-python/Recursion_turtleDrawSierpinski.py
# ../data/github-repos/files/mediassumani/TechInterviewPrep/InterviewPrepKit/LinkedList/cycle.py
# ../data/github-repos/files/mediassumani/TechInterviewPrep/InterviewPrepKit/Trees/height_balanced_tree.py
# ../data/github-repos/files/canokaue/ImmunoLynk/result_recognition_old/eye_status.py
# ../data/github-repos/files/milvus-io/bootcamp/benchmark_test/concurrent-test/multi_process_search.py
# ../data/github-repos/files/IvLabs/person_following_bot/bonus/renumber.py
# ../data/github-repos/files/skytreader/pydagogical/algorithms/hashfun.py
# ../data/github-repos/files/skytreader/pydagogical/algorithms/graph_coloring.py
#   0%|                                                                                                                                                                                | 0/12272 [00:00<?, ?it/s]/tmp/ipykernel_22901/3039120628.py:55: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   root = random.sample(left, 1)[0]
# /tmp/ipykernel_22901/3039120628.py:66: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   consider = random.sample(consider, min(len(consider), 200 - len(keep)))
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12272/12272 [03:03<00:00, 66.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12272/12272 [01:26<00:00, 141.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12272/12272 [02:39<00:00, 76.72it/s]

# %%
f = open('../data/repos.jsonl', 'w')
json.dump(repos, fp = f)
f.close()
f = open('../data/dataset.jsonl', 'w')
json.dump(dataset, fp = f)
f.close()
f = open('../data/graphs.jsonl', 'w')
json.dump(graphs, fp = f)
f.close()
f = open('../data/labels01.jsonl', 'w')
json.dump(labels01, fp = f)
f.close()
f = open('../data/description.jsonl', 'w')
json.dump(description, fp = f)
f.close()
f = open('../data/readme.jsonl', 'w')
json.dump(readme, fp = f)
f.close()
